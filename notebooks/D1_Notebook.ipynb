# %% [markdown]
# # Run ribofilio on D1 using default parameters

# %%
 # %run ../src/ribofilio.py -t yeast.fa -f SRR5090936.bed -r SRR5090934.bed -o D1
# Out:
# Initializing and reading arguments
# Plot mode is on, regression plots will be printed
# Reading transcripts
# yeast.fa
# .....................
# .....................
# .....................
# .....................
# .....................
# .....................
# max_gene_length is 14733
# Done reading transcripts
# Reading ribosome footprint SRR5090936.bed
# .....................
# .....................
# Filling coverage matrix
# Filling positions matrix
# Started binning process
# Reading mRNA SRR5090934.bed
# .....................
# .....................
# .....................
# .....................
# Filling coverage matrix
# No. of bins: 295
# Done binning, starting regression and plotting
# ----------------------------------------
# Weighted Linear Regression
# ----------------------------------------
# Dropoff Rate : -0.0051
# Dropoff per codon: [[-0.0003]]
# Standard Error is (SE): [0.0007]
# Confidence Interval is: [ -0.0051 +/- [0.0013] ]
# ...

# %% [markdown]
# # Let's see the output files

# %%
ls
# Out:
# D1.Log.WLR.png     D1_Notebook.ipynb  SRR5090936.bed
# D1.regression.log  SRR5090934.bed     yeast.fa

# %% [markdown]
# # Show the regression output

# %%
from IPython.display import Image
Image(filename='D1.Log.WLR.png')

# %% [markdown]
# # Run Ribofilio on D1 and on a subset of Gene Ontology genes (GO:0000462.txt)

# %%
 # %run ../src/ribofilio.py -t yeast.fa -f SRR5090936.bed -r SRR5090934.bed -s GO:0000462.txt -o D1_GO0000462
# Out:
# Initializing and reading arguments
# Plot mode is on, regression plots will be printed
# Reading transcripts
# Maximum gene length is 5310
# Done reading transcripts
# Reading ribosome footprint SRR5090936.bed
# .....................
# .....................
# Filling coverage matrix
# Filling positions matrix
# Started binning process
# Reading mRNA SRR5090934.bed
# .....................
# .....................
# .....................
# .....................
# Filling coverage matrix
# No. of bins: 107
# Done binning, starting regression and plotting
# ----------------------------------------
# Weighted Linear Regression
# ----------------------------------------
# Dropoff Rate : -0.0136
# Dropoff per codon: [[-0.0008]]
# Standard Error is (SE): [0.0028]
# Confidence Interval is: [ -0.0136 +/- [0.0055] ]
# Root Mean Squared Error (RMSE):  0.3201
# R2 Score:  -0.427
# T-test score:  [-4.87027636]
# Pvalue: [0.0198]
# All is done

# %% [markdown]
# # Lets see the regression plots

# %%
from IPython.display import Image
Image(filename='D1_GO0000462.Log.WLR.png')
