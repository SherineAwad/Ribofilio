# %%
import sklearn
import matplotlib
from IPython.display import Image
from IPython.display import display

# %% [markdown]
# # Synthetic Defined: FP is SRR9670822  and mRNA is SRR9670820

# %%
# %run ../src/ribofilio.py -t yeast.fa -f SRR9670822.bed -r SRR9670820.bed -o SRR9670822 -p 1
# Out:
# Initializing and reading arguments
# Plot mode is on, regression plots will be printed
# Reading transcripts
# .....................
# .....................
# .....................
# .....................
# .....................
# .....................
# max_gene_length is 14733
# Done reading transcripts
# Reading ribosome footprint SRR9670822.bed
# .....................
# .....................
# Reading mRNA SRR9670820.bed
# .....................
# .....................
# .....................
# Filling coverage matrix
# Filling positions matrix
# Started binning porcess
# No. of bins: 295
# Done binning, starting regression and plotting
# ----------------------------------------
# Dropoff Rate: [[-0.01017721]]
# Root mean squared error:  0.025010717957842227
# R2 score:  0.6887198845757956
# ----------------------------------------
# Regression is done
# Plotting is done
# All is done

# %% [markdown]
# # Weighter Linear Regression in Linear Mode

# %%
Image(filename='SRR9670822_SRR9670820_50.Linear.WLR.png')

# %% [markdown]
# # Weighter Linear Regression in Log Mode

# %%
Image(filename='SRR9670822_SRR9670820_50.Log.WLR.png')

# %% [markdown]
# # Distribution of shuffled slopes

# %%
Image(filename='SRR9670822_SRR9670820.slopes.png')

# %% [markdown]
# # Dropoff rate based on Genome Length

# %%
a = Image(filename='SRR9670822_SRR9670820-yeast02000_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-yeast02000.slopes.png')
display(a, b)

# %%
a = Image(filename='SRR9670822_SRR9670820-yeast20004000_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-yeast20004000.slopes.png')
display(a,b)

# %%
a = Image(filename='SRR9670822_SRR9670820-yeast40006000_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-yeast40006000.slopes.png')
display(a,b)

# %%
a = Image(filename='SRR9670822_SRR9670820-yeast6000100000_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-yeast6000100000.slopes.png')
display(a,b)

# %% [markdown]
# # Dropoff rate based on Gene Ontology

# %% [markdown]
# ### GO0006406: The directed movement of mRNA from the nucleus to the cytoplasm

# %%
a = Image(filename='SRR9670822_SRR9670820-GO0006406_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-GO0006406.slopes.png')
display(a,b)

# %% [markdown]
# ### GO0006950 Response to stress

# %%
a = Image(filename='SRR9670822_SRR9670820-GO0006950_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-GO0006950.slopes.png')
display(a,b)

# %% [markdown]
# ### GO0009651 Response to salt stress

# %%
a = Image(filename='SRR9670822_SRR9670820-GO0009651_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-GO0009651.slopes.png')
display(a,b)

# %% [markdown]
# ### GO0006412 Translation

# %%
a = Image(filename='SRR9670822_SRR9670820-GO0006412_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-GO0006412.slopes.png')
display(a,b)

# %% [markdown]
# ### GO0007049 Cell Cycle

# %%
a = Image(filename='SRR9670822_SRR9670820-GO0007049_50.Log.WLR.png')
b = Image(filename='SRR9670822_SRR9670820-GO0007049.slopes.png')
display(a,b)
